# %% [markdown]
# # Creating Data frame

# %%
import pandas as pd

# %%
path1="C:\\Users\\hp\\Downloads\\geo prafrance list  (1).xlsx"
sample_data=pd.read_excel(path1)
sample_data
# Out:
#     Preference            Degree / Course Name  \
# 0            1  B.A. (Hons.) Political Science
# 1            2  B.A. (Hons.) Political Science
# 2            3            B.A. (Hons.) History
# 3            4  B.A. (Hons.) Political Science
# 4            5          B.A. (Hons.) Geography
# ..         ...                             ...
# 57          58          B.A. (Hons.) Economics
# 58          59          B.A. (Hons.) Economics
# 59          60            B.A. (Hons.) History
# 60          61            B.A. (Hons.) History
# 61          62            B.A. (Hons.) History
#
#                                College Name   Campus Type  \
# 0                             Hindu College  North Campus
# 1                  Sri Venkateswara College  South Campus
# 2                             Hindu College  North Campus
# 3                        Kirori Mal College  North Campus
# 4                        Kirori Mal College  North Campus
# ...
